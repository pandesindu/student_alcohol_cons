# %%
# import pandas 
import pandas as pd
# import numpy
import numpy as np
# import matplotlib
import matplotlib.pyplot as plt
# import seaborn
import seaborn as sns

# %%
# load the dataset
df = pd.read_csv("dataset/student-mat.csv")

# print the first 5 rows of the dataframe.
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
# data information
# school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# sex - student's sex (binary: 'F' - female or 'M' - male)
# age - student's age (numeric: from 15 to 22)
# address - student's home address type (binary: 'U' - urban or 'R' - rural)
# famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# schoolsup - extra educational support (binary: yes or no)
# famsup - family educational support (binary: yes or no)
# paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# activities - extra-curricular activities (binary: yes or no)
# nursery - attended nursery school (binary: yes or no)
# higher - wants to take higher education (binary: yes or no)
# internet - Internet access at home (binary: yes or no)
# romantic - with a romantic relationship (binary: yes or no)
# famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# health - current health status (numeric: from 1 - very bad to 5 - very good)
# absences - number of school absences (numeric: from 0 to 93)
# These grades are related with the course subject, Math or Portuguese:

# G1 - first period grade (numeric: from 0 to 20)
# G2 - second period grade (numeric: from 0 to 20)
# G3 - final grade (numeric: from 0 to 20, output target)

# %%
# encode the data object to numeric
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_tranform= df.apply(le.fit_transform)

# %%
# looking coorelation between variables using heatmap
plt.figure(figsize=(30,30))
sns.heatmap(df_tranform.corr(), annot=True, fmt='.0%')
# Out:
# <AxesSubplot:>

# %%
# select a subset of the dataframe is connected with the columns WALC
df = df[['age', 'sex', 'address', 'famsize', 'Pstatus', 'failures', 'internet','romantic', 'famrel', 'freetime', 'goout', 'absences','health','Dalc', 'Walc']]
df.head()
# Out:
#    age sex address famsize Pstatus  failures internet romantic  famrel  \
# 0   18   F       U     GT3       A         0       no       no       4
# 1   17   F       U     GT3       T         0      yes       no       5
# 2   15   F       U     LE3       T         3      yes       no       4
# 3   15   F       U     GT3       T         0      yes      yes       3
# 4   16   F       U     GT3       T         0       no       no       4
#
#    freetime  goout  absences  health  Dalc  Walc
# 0         3      4         6       3     1     1
# 1         3      3         4       3     1     1
# 2         3      2        10       3     2     3
# 3         2      2         2       5     1     1
# 4         3      2         4       5     1     2

# %%
# plot histogram data age, famrel, freetime, goout, absences, health, dalc, walc using seaborn in one row and two columns
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
sns.distplot(df['age'], ax=axes[0])
sns.distplot(df['famrel'], ax=axes[1])
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
sns.distplot(df['freetime'], ax=axes[0])
sns.distplot(df['goout'], ax=axes[1])
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
sns.distplot(df['absences'], ax=axes[0])
sns.distplot(df['health'], ax=axes[1])
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
sns.distplot(df['Dalc'], ax=axes[0])
sns.distplot(df['Walc'], ax=axes[1])
# Out:
# c:\Users\sindu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\sindu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# make plot of data binary is internet, romantic, sex, address, famsize,Pstatus,using seaborn 
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20,10))
sns.countplot(df['internet'], ax=axes[0,0])
sns.countplot(df['romantic'], ax=axes[0,1])
sns.countplot(df['sex'], ax=axes[0,2])
sns.countplot(df['address'], ax=axes[1,0])
sns.countplot(df['famsize'], ax=axes[1,1])
# Out:
# c:\Users\sindu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\sindu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\sindu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
# make distribution plot of data age and walc in barplot using seaborn
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
sns.barplot(x='age', y='Walc', data=df, ax=axes[0])
sns.barplot(x='age', y='Dalc', data=df, ax=axes[1])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Dalc'>

# %%
# make barplot of sex and walc using seaborn
sns.barplot(x='sex', y='Walc', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Walc'>

# %%
# make barplot of dalc and walc using seaborn
sns.barplot(x='Dalc', y='Walc', data=df)
# Out:
# <AxesSubplot:xlabel='Dalc', ylabel='Walc'>

# %%
# make a barplot of goout and walc using seaborn
sns.barplot(x='goout', y='Walc', data=df)
# Out:
# <AxesSubplot:xlabel='goout', ylabel='Walc'>

# %%
# make a barplot of famrel, romantic and walc using seaborn in one row and two columns
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
sns.barplot(x='famrel', y='Walc', data=df, ax=axes[0])
sns.barplot(x='romantic', y='Walc', data=df, ax=axes[1])
# Out:
# <AxesSubplot:xlabel='romantic', ylabel='Walc'>

# %%
# encode the categorical data to numerical data
df['address'] = df['address'].map({'U': 0, 'R': 1})
df['sex'] = df['sex'].map({'F': 0, 'M': 1})
df['Pstatus'] = df['Pstatus'].map({'A': 0, 'T': 1})
df['romantic'] = df['romantic'].map({'no': 0, 'yes': 1})
df['famsize'] = df['famsize'].map({'LE3': 0, 'GT3': 1})
df['internet'] = df['internet'].map({'no': 0, 'yes': 1})
df.head()
# Out:
#    age  sex  address  famsize  Pstatus  failures  internet  romantic  famrel  \
# 0   18    0        0        1        0         0         0         0       4
# 1   17    0        0        1        1         0         1         0       5
# 2   15    0        0        0        1         3         1         0       4
# 3   15    0        0        1        1         0         1         1       3
# 4   16    0        0        1        1         0         0         0       4
#
#    freetime  goout  absences  health  Dalc  Walc
# 0         3      4         6       3     1     1
# 1         3      3         4       3     1     1
# 2         3      2        10       3     2     3
# 3         2      2         2       5     1     1
# 4         3      2         4       5     1     2

# %%
# plot correlation of teh dataset
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True, fmt='.0%')
plt.show()

# %%
# split the data into independent 'X' and dependent 'Y' variables
X = df.iloc[:, :-1].values
Y = df.iloc[:, -1].values

print(X)
# Out:
# [[18  0  0 ...  6  3  1]
#  [17  0  0 ...  4  3  1]
#  [15  0  0 ... 10  3  2]
#  ...
#  [21  1  1 ...  3  3  3]
#  [18  1  1 ...  0  5  3]
#  [19  1  0 ...  5  5  3]]

# %%
# standardize the data using minmaxscaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
print(X)
# Out:
# [[0.42857143 0.         0.         ... 0.08       0.5        0.        ]
#  [0.28571429 0.         0.         ... 0.05333333 0.5        0.        ]
#  [0.         0.         0.         ... 0.13333333 0.5        0.25      ]
#  ...
#  [0.85714286 1.         1.         ... 0.04       0.5        0.5       ]
#  [0.42857143 1.         1.         ... 0.         1.         0.5       ]
#  [0.57142857 1.         0.         ... 0.06666667 1.         0.5       ]]

# %%
# split the dataset into 80% training and 20% testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
# import sklearn 
import sklearn
def fit_predict(regressor):
    regressor.fit(X_train, y_train)
    y_pred = regressor.predict(X_test)
    print('Accuracy Score: ', regressor.score(X_test, y_test))
    print('Mean Absolute Error: ', sklearn.metrics.mean_absolute_error(y_test, y_pred))
    print('Mean Squared Error: ', sklearn.metrics.mean_squared_error(y_test, y_pred))
    print('Root Mean Squared Error: ', np.sqrt(sklearn.metrics.mean_squared_error(y_test, y_pred)))

# %%
# import the regressor
from sklearn.linear_model import LinearRegression
# create a regressor object
regressor = LinearRegression()
# fit the regressor with X and Y data
fit_predict(regressor)
# Out:
# Accuracy Score:  0.48896582109456965
# Mean Absolute Error:  0.7831793357503782
# Mean Squared Error:  0.8198164074989855
# Root Mean Squared Error:  0.905437136138664

# %%
# import random forest regressor
from sklearn.ensemble import RandomForestRegressor
# create a regressor object
regressor = RandomForestRegressor(random_state = 2)
# fit the regressor with X and Y data
fit_predict(regressor)
# Out:
# Accuracy Score:  0.46576841789852175
# Mean Absolute Error:  0.7893670886075947
# Mean Squared Error:  0.8570303797468354
# Root Mean Squared Error:  0.9257593530431304

# %%
# import the decision tree regressor
from sklearn.tree import DecisionTreeRegressor
# create a regressor object
regressor = DecisionTreeRegressor(max_leaf_nodes=99,random_state = 0)
# fit the regressor with X and Y data
fit_predict(regressor)
# Out:
# Accuracy Score:  0.22070442962668102
# Mean Absolute Error:  0.8191098142363964
# Mean Squared Error:  1.2501694040342364
# Root Mean Squared Error:  1.1181097459705092

# %%
# import the support vector regressor
from sklearn.svm import SVR
# create a regressor object
regressor = SVR(kernel = 'rbf')
# fit the regressor with X and Y data
fit_predict(regressor)
# Out:
# Accuracy Score:  0.44404583545619714
# Mean Absolute Error:  0.807545537665998
# Mean Squared Error:  0.8918784001622424
# Root Mean Squared Error:  0.9443931385616069

# %%
# import the gradient boosting regressor
from sklearn.ensemble import GradientBoostingRegressor
# create a regressor object
regressor = GradientBoostingRegressor(n_estimators=100,random_state = 0)
# fit the regressor with X and Y data
fit_predict(regressor)
# Out:
# Accuracy Score:  0.4385902502877156
# Mean Absolute Error:  0.7632786102689032
# Mean Squared Error:  0.9006304140553423
# Root Mean Squared Error:  0.9490154972682703

# %%
# import the xgboost regressor
from xgboost import XGBRegressor
# create a regressor object
regressor = XGBRegressor()
# fit the regressor with X and Y data
fit_predict(regressor)
# Out:
# Accuracy Score:  0.38526292834372555
# Mean Absolute Error:  0.8311198814005791
# Mean Squared Error:  0.9861797086080147
# Root Mean Squared Error:  0.9930658128281402
